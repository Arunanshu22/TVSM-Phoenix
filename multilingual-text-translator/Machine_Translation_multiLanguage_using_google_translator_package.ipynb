# %%
#!pip install --upgrade googletrans
#pip install --upgrade googletrans==4.0.0-rc1

#################Google Translator ###########################
from googletrans import Translator

translator = Translator()

query = "your text to translate"
translated = translator.translate(query, dest='bn')  # Set 'bn' for Bengali

print(translated.text)
# Out:
# আপনার পাঠ্য অনুবাদ

# %%
########################################################################

# %%
import pandas as pd
import googletrans
from googletrans import Translator
translator = Translator()
pd.set_option('max_colwidth', 300)
# how to get the supported language and their corresponing code
lang_df = pd.DataFrame.from_dict(googletrans.LANGUAGES,  orient='index', columns=['Language'])
lang_df
# Out:
#      Language
# af  afrikaans
# sq   albanian
# am    amharic
# ar     arabic
# hy   armenian
# ..        ...
# cy      welsh
# xh      xhosa
# yi    yiddish
# yo     yoruba
# zu       zulu
#
# [107 rows x 1 columns]

# %%
#################Google Translator ###########################
from googletrans import Translator

translator = Translator()

query = "This is an example"
translated = translator.translate(query, dest='hi')  # Set 'bn' for Bengali

print(translated.text)
# Out:
# यह एक उदाहरण है

# %%
# find the code for english, french, italian, spanish and greek
lang_df[lang_df.Language.isin(['english', 'french', 'italian', 'spanish', 'greek'])]
# Out:
#    Language
# en  english
# fr   french
# el    greek
# it  italian
# es  spanish

# %%
#Show the detected language
my_example = translator.detect("Cerco un centro di gravità permanente")
print(my_example)
# Out:
# Detected(lang=it, confidence=None)

# %%
#Translate to english
my_translation = translator.translate("Cerco un centro di gravità permanente", src='it', dest='en')
print(my_translation.text)
# Out:
# I am looking for a permanent center of gravity

# %%
#How to translate multiple documents at once -> ENg to Italian

my_example = pd.DataFrame({'EnglishText':['Police in France say they have seized 140,000 face masks that were destined for sale on the black market.',
'Officers say they discovered the haul when they spotted a businessman unloading the masks from a lorry into a house in St Denis, north of Paris.',
'Prime Minister Boris Johnson could possibly lead the daily news conference on Monday but, if not then, it will be pretty soon afterwards.']})
my_example['ItalianText'] = my_example['EnglishText'].apply(lambda x: translator.translate(x, src='en', dest='it').text )
my_example
# Out:
#                                                                                                                                         EnglishText  \
# 0                                         Police in France say they have seized 140,000 face masks that were destined for sale on the black market.
# 1  Officers say they discovered the haul when they spotted a businessman unloading the masks from a lorry into a house in St Denis, north of Paris.
# 2         Prime Minister Boris Johnson could possibly lead the daily news conference on Monday but, if not then, it will be pretty soon afterwards.
#
#                                                                                                                                                          ItalianText
# 0                                                          La polizia in Francia afferma di aver sequestrato 140.000 maschere per il viso destinate al mercato nero.
# 1  Gli agenti dicono di aver scoperto il raggio quando hanno visto un uomo d'affari che scaricava le maschere da un camion in una casa a St Denis, a nord di Parigi.
# 2                             Lunedì il primo ministro Boris Johnson potrebbe guidare la conferenza stampa quotidiana ma, in caso contrario, sarà molto presto dopo.

# %%
#How to translate multiple documents at once -> Eng to Hindi

my_example = pd.DataFrame({'EnglishText':['Police in France say they have seized 140,000 face masks that were destined for sale on the black market.',
'Officers say they discovered the haul when they spotted a businessman unloading the masks from a lorry into a house in St Denis, north of Paris.',
'Prime Minister Boris Johnson could possibly lead the daily news conference on Monday but, if not then, it will be pretty soon afterwards.']})
my_example['ItalianText'] = my_example['EnglishText'].apply(lambda x: translator.translate(x, src='en', dest='hi').text )
my_example
# Out:
#                                                                                                                                         EnglishText  \
# 0                                         Police in France say they have seized 140,000 face masks that were destined for sale on the black market.
# 1  Officers say they discovered the haul when they spotted a businessman unloading the masks from a lorry into a house in St Denis, north of Paris.
# 2         Prime Minister Boris Johnson could possibly lead the daily news conference on Monday but, if not then, it will be pretty soon afterwards.
#
#                                                                                                                                                           ItalianText
# 0                                             फ्रांस में पुलिस का कहना है कि उन्होंने 140,000 फेस मास्क जब्त किए हैं जो ब्लैक मार्केट पर बिक्री के लिए किस्मत में थे।
# 1  अधिकारियों का कहना है कि उन्होंने पेरिस के उत्तर में सेंट डेनिस में एक घर में एक लॉरी से मास्क को उतारते हुए एक व्यवसायी को देखा, जब उन्होंने एक व्यवसायी को देखा।
# 2                            प्रधान मंत्री बोरिस जॉनसन संभवतः सोमवार को डेली न्यूज सम्मेलन का नेतृत्व कर सकते हैं, लेकिन यदि नहीं, तो यह बहुत जल्द ही बहुत जल्द होगा।
