# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/testingdataontwentytofive/archive/model/fivespeakertwentytofivemodel.joblib
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/tf_Wav_reader.py
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/611.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/364.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/367.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/116.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/374.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/485.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/456.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/626.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/590.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/296.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1180.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/66.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/468.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/526.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/339.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/956.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/300.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/493.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/688.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/947.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/510.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/229.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/721.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/497.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/162.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/600.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1122.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/671.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/818.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/17.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/88.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/482.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/138.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/244.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1159.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/136.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/786.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/644.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/599.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/862.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/274.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/163.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1058.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/164.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/255.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/85.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1074.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/835.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/783.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1111.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1006.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/158.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/279.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/953.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/291.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1036.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/174.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/917.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/813.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/226.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/715.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/570.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/999.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/98.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/380.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/288.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/414.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/909.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1154.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/932.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1014.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/467.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/710.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/317.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/204.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/251.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1029.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/387.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1010.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/831.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/122.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/321.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/659.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/79.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/806.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/763.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/129.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/730.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/652.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/293.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/185.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1063.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/442.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/267.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1042.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/563.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/148.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1075.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/260.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1161.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1022.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/441.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1186.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1197.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/913.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/10.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1102.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/33.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1012.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/584.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/574.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/284.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/71.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/841.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/217.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/874.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/215.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/634.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1121.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/295.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/963.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1168.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/747.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/690.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/800.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/615.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/907.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/637.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/290.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/96.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/347.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/957.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/152.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/663.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1106.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/964.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/541.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/848.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/192.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/36.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/429.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/755.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1100.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/257.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/530.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/761.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/263.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/512.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1199.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/717.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/4.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/111.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/959.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1149.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/519.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/972.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1005.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1019.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/449.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/601.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/578.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1083.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/635.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/308.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/60.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/361.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/345.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/771.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1062.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/409.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/641.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/646.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/170.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/857.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/816.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/612.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1110.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/198.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/855.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1055.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/196.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/231.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/70.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/294.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1142.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/627.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/839.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1113.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/744.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/629.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/102.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/643.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/978.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/325.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/222.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/533.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/250.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/110.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/416.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/656.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/108.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/127.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1188.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1066.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/887.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/880.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/951.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/435.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1085.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/154.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/973.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/582.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/785.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/209.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/680.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/285.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/521.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1098.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/176.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/354.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/95.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1016.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/78.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/801.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/753.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/935.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1033.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/447.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/982.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/369.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/478.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/235.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/607.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/969.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/388.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1013.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/253.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/258.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/268.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/937.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/967.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/336.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1167.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/950.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/691.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/109.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/119.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/914.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/992.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/94.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1049.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1099.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1018.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/310.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1052.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/379.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/794.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/803.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1038.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1000.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/685.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1183.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/742.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1081.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1077.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/940.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/14.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1059.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1119.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/417.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/777.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/531.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/523.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/708.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/261.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/544.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/561.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/724.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/550.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/871.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/571.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1141.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1048.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/461.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/481.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/370.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/958.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/890.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/834.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1060.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/674.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/620.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/452.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/564.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1032.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/455.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/677.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1105.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/157.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/810.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/40.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/699.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/51.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/271.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/602.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/334.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/436.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1024.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1192.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1108.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/186.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/896.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/502.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/329.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/139.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/74.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/474.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/205.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/716.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/247.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1150.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/405.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/408.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/92.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1034.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/711.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/404.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1020.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/994.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/655.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/823.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1053.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/410.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/640.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/974.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/376.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/475.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/221.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/927.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/434.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1127.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/875.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/990.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/892.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/895.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1172.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/769.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/448.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/193.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/254.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/283.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/745.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/227.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/412.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/758.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1126.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/76.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/399.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1031.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/143.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/928.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/64.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/130.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1051.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/662.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/936.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1116.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/630.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/203.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/277.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/925.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1067.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/89.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/181.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1040.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/568.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/667.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/328.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/487.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1088.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/997.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/996.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1181.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/911.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/202.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/670.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/559.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/286.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/593.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1001.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/888.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/647.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1173.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/625.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/419.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/631.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/504.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/945.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/398.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/682.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/44.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/479.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/930.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/54.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/908.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/985.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/19.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/427.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/353.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/11.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1129.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/303.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/491.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/126.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/457.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/275.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/817.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1101.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1073.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/470.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/103.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1037.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/460.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/211.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1070.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/359.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/190.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/151.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/661.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1114.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/516.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1091.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/814.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/739.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/654.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1169.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/900.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/218.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/819.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/207.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/144.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/469.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/243.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/104.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1030.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/397.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/272.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1132.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/740.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/539.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1133.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/617.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/970.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/916.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/926.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/153.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/704.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/562.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1090.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/365.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/87.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/732.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/486.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/446.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/386.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/348.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1124.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/547.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/381.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/614.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/75.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/349.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/16.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/281.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1007.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/137.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/437.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/20.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/525.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/749.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1164.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/9.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1045.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1148.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/906.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/450.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/815.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/273.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/589.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/356.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1123.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/147.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/565.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/371.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/426.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/56.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/168.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/538.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/106.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/603.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/259.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/5.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/175.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/312.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1008.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1095.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1117.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/822.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/748.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/554.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1178.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/776.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/21.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/503.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/549.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/344.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/507.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/847.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/851.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/322.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1035.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1027.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/333.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/976.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/825.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/169.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/61.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/82.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/638.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/920.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/965.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/167.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/795.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/938.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/39.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/903.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/331.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/772.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/604.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/302.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1043.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1072.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/47.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/462.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1028.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/145.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/45.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/292.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/499.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/171.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1015.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/120.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/838.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/845.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1140.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/666.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/885.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/269.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/623.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/651.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/67.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/155.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/149.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/949.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/861.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1139.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/32.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/206.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1171.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/576.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/142.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/645.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/346.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1179.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/902.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/178.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/606.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/373.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/444.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/423.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/1151.wav
# /kaggle/input/testingdataontwentytofive/archive/16000_pcm_speeches/Shivam/287.wav
# ...
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/391.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/439.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/31.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/330.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/319.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/52.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/390.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/187.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/83.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/337.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/458.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/360.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/318.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/132.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/25.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/425.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/363.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/63.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/38.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/210.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/194.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/415.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/43.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/240.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/59.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/55.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/77.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/184.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/156.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/49.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/3.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/34.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/179.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/29.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/430.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/355.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/246.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/183.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/443.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/124.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/342.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/123.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/289.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/73.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/62.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/306.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/256.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/177.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/91.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/323.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/197.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/8.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/230.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/113.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/107.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/307.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/445.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/165.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/420.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/282.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/305.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/234.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/335.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/182.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/400.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/403.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/422.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/351.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/375.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/72.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/201.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/23.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/65.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/402.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/315.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/338.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/237.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/432.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/135.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/265.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/22.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/140.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/225.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/343.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/161.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/453.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/27.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/146.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/160.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/166.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/212.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/264.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/372.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/97.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/99.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/216.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/428.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/276.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/12.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/413.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/112.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/421.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/304.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/324.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/278.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/252.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/15.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/327.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/241.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/352.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/150.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/18.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/131.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/53.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/309.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/424.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/378.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/213.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/100.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/393.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/394.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/220.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/262.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/101.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/30.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/141.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/214.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/401.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/377.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/411.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/37.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/208.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/440.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/117.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/297.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/69.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/357.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/341.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/93.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/228.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/350.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/362.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/105.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/80.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/57.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/326.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/191.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/368.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/248.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/2.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/219.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/314.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/35.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/242.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/382.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/232.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/249.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/134.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/298.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/392.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/454.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/189.wav
# /kaggle/input/testingdataontwentytofive/archive/kaggletestdata/16000_pcm_speeches/Anirban/188.wav

# %%
import tensorflow as tf
import os
from os.path import isfile, join
import numpy as np
import shutil
from tensorflow import keras
from pathlib import Path
from IPython.display import display, Audio
import subprocess
# Out:
# 2024-02-14 10:19:51.350368: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-14 10:19:51.350576: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-14 10:19:51.519577: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !cp -r "../input/testingdataontwentytofive/archive" ./

# %%
data_directory = "/kaggle/working/archive/16000_pcm_speeches"
audio_folder = "audio"
noise_folder = "noise"

audio_path = os.path.join(data_directory, audio_folder)
noise_path = os.path.join(data_directory, noise_folder)

# %%
audio_path
# Out:
# '/kaggle/working/archive/16000_pcm_speeches/audio'

# %%
valid_split = 0.1

shuffle_seed = 43

sample_rate = 16000

scale = 0.5

batch_size = 128

epochs = 15

# %%
for folder in os.listdir(data_directory):
    if os.path.isdir(os.path.join(data_directory, folder)):
        if folder in [audio_folder, noise_folder]:
            
            continue
        elif folder in ["other", "_background_noise_"]:
            
            shutil.move(
                os.path.join(data_directory, folder),
                os.path.join(noise_path, folder),
            )
        else:
            shutil.move(
                os.path.join(data_directory, folder),
                os.path.join(audio_path, folder),
            )

# %%
noise_paths = []
for subdir in os.listdir(noise_path):
    subdir_path = Path(noise_path) / subdir
    if os.path.isdir(subdir_path):
        noise_paths += [
            os.path.join(subdir_path, filepath)
            for filepath in os.listdir(subdir_path)
            if filepath.endswith(".wav")
        ]

# %%
noise_paths
# Out:
# ['/kaggle/working/archive/16000_pcm_speeches/noise/_background_noise_/10convert.com_Audience-Claps_daSG5fwdA7o.wav',
#  '/kaggle/working/archive/16000_pcm_speeches/noise/_background_noise_/doing_the_dishes.wav',
#  '/kaggle/working/archive/16000_pcm_speeches/noise/_background_noise_/running_tap.wav',
#  '/kaggle/working/archive/16000_pcm_speeches/noise/_background_noise_/dude_miaowing.wav',
#  '/kaggle/working/archive/16000_pcm_speeches/noise/other/exercise_bike.wav',
#  '/kaggle/working/archive/16000_pcm_speeches/noise/other/pink_noise.wav']

# %%
command = (
    "for dir in `ls -1 " + noise_path + "`; do "
    "for file in `ls -1 " + noise_path + "/$dir/*.wav`; do "
    "sample_rate=`ffprobe -hide_banner -loglevel panic -show_streams "
    "$file | grep sample_rate | cut -f2 -d=`; "
    "if [ $sample_rate -ne 16000 ]; then "
    "ffmpeg -hide_banner -loglevel panic -y "
    "-i $file -ar 16000 temp.wav; "
    "mv temp.wav $file; "
    "fi; done; done"
)

# %%
os.system(command)
def load_noise_sample(path):
    sample, sampling_rate = tf.audio.decode_wav(
        tf.io.read_file(path), desired_channels=1
    )
    if sampling_rate == sample_rate:
        slices = int(sample.shape[0] / sample_rate)
        sample = tf.split(sample[: slices * sample_rate], slices)
        return sample
    else:
        print("Sampling rate for",path, "is incorrect")
        return None


noises = []
for path in noise_paths:
    sample = load_noise_sample(path)
    if sample:
        noises.extend(sample)
noises = tf.stack(noises)

# %%
def paths_and_labels_to_dataset(audio_paths, labels):
    path_ds = tf.data.Dataset.from_tensor_slices(audio_paths)
    audio_ds = path_ds.map(lambda x: path_to_audio(x))
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((audio_ds, label_ds))

# %%
def path_to_audio(path):
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1, sample_rate)
    return audio

# %%
def add_noise(audio, noises=None, scale=0.5):
    if noises is not None:
        tf_rnd = tf.random.uniform(
            (tf.shape(audio)[0],), 0, noises.shape[0], dtype=tf.int32
        )
        noise = tf.gather(noises, tf_rnd, axis=0)

        prop = tf.math.reduce_max(audio, axis=1) / tf.math.reduce_max(noise, axis=1)
        prop = tf.repeat(tf.expand_dims(prop, axis=1), tf.shape(audio)[1], axis=1)

        audio = audio + noise * prop * scale

    return audio

# %%
def audio_to_fft(audio):
    audio = tf.squeeze(audio, axis=-1)
    fft = tf.signal.fft(
        tf.cast(tf.complex(real=audio, imag=tf.zeros_like(audio)), tf.complex64)
    )
    fft = tf.expand_dims(fft, axis=-1)

    return tf.math.abs(fft[:, : (audio.shape[1] // 2), :])

# %%
class_names = os.listdir(audio_path)
print(class_names,)

audio_paths = []
labels = []
for label, name in enumerate(class_names):
    print("Speaker:",(name))
    dir_path = Path(audio_path) / name
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)
        if filepath.endswith(".wav")
    ]
    audio_paths += speaker_sample_paths
    labels += [label] * len(speaker_sample_paths)
# Out:
# ['Arunanshu', 'Abhishek', 'Anirban', 'Shivam', 'Sunamdha']
# Speaker: Arunanshu
# Speaker: Abhishek
# Speaker: Anirban
# Speaker: Shivam
# Speaker: Sunamdha

# %%
rng = np.random.RandomState(shuffle_seed)
rng.shuffle(audio_paths)
rng = np.random.RandomState(shuffle_seed)
rng.shuffle(labels)

# %%
# Split into training and validation
num_val_samples = int(valid_split * len(audio_paths))
train_audio_paths = audio_paths[:-num_val_samples]
train_labels = labels[:-num_val_samples]


valid_audio_paths = audio_paths[-num_val_samples:]
valid_labels = labels[-num_val_samples:]

# %%
# Create datasets, one for training and the other for validation
train_ds = paths_and_labels_to_dataset(train_audio_paths, train_labels)
train_ds = train_ds.shuffle(buffer_size=batch_size * 8, seed=shuffle_seed).batch(
    batch_size
)

valid_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
valid_ds = valid_ds.shuffle(buffer_size=32 * 8, seed=shuffle_seed).batch(32)

# %%
# Add noise to the training set
train_ds = train_ds.map(
    lambda x, y: (add_noise(x, noises, scale=scale), y),
    num_parallel_calls=tf.data.experimental.AUTOTUNE,
)

# Transform audio wave to the frequency domain using `audio_to_fft`
train_ds = train_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
)

train_ds = train_ds.prefetch(tf.data.experimental.AUTOTUNE)

valid_ds = valid_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
)
valid_ds = valid_ds.prefetch(tf.data.experimental.AUTOTUNE)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Dropout

# %%
import joblib

# Load the model
loaded_model = joblib.load("/kaggle/working/archive/model/fivespeakertwentytofivemodel.joblib")

# Make predictions on the training dataset
test_loss, test_accuracy = loaded_model.evaluate(valid_ds)
# Assuming train_ds is a DataFrame, you can print the predictions
print( test_accuracy)
# Out:
# 19/19 [==============================] - 16s 832ms/step - loss: 19.8008 - accuracy: 0.1812
# 0.1812080591917038

# %%
loaded_model.evaluate(train_ds)
# Out:
# 42/42 [==============================] - 138s 3s/step - loss: 17.9550 - accuracy: 0.2022
# [17.954973220825195, 0.2021593451499939]
