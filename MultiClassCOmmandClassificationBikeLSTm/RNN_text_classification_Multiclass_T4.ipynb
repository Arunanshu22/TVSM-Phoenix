# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.utils import to_categorical

# Load your dataset
df = pd.read_csv("../DataSet/Commands_Classification_Dataset2.csv",encoding="latin1")  # Update with your dataset filename
# Out:
# WARNING:tensorflow:From C:\Users\anirban.saha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df
# Out:
#         Class    Subclass SubclassCategory  \
# 0        Bike        Edge     Battery/Fuel
# 1        Bike        Edge     Battery/Fuel
# 2        Bike        Edge     Battery/Fuel
# 3        Bike        Edge     Battery/Fuel
# 4        Bike        Edge     Battery/Fuel
# ...       ...         ...              ...
# 2975  NonBike  Not needed               NC
# 2976  NonBike  Not needed               NC
# 2977  NonBike  Not needed               NC
# 2978  NonBike  Not needed               NC
# 2979  NonBike  Not needed               NC
#
#                                                Commands  \
# 0                     What is my current battery level?
# 1          How much range do I have left on my battery?
# 2        When was the last time my battery was charged?
# 3           How long until my battery is fully charged?
# 4     How long should I charge my vehicle for a suff...
# ...                                                 ...
# 2975                           Perform my pets marriage
# 2976                           Perform my dogs marriage
# 2977                               check blood pressure
# 2978                            check balloon pressure
# 2979                                     check my books
#
#                        Response  Label
# 0          Updating please wait      1
# 1          Updating please wait      1
# 2          Updating please wait      1
# 3          Updating please wait      1
# 4          Updating please wait      1
# ...                         ...    ...
# 2975  It is a  non bike command      0
# 2976  It is a  non bike command      0
# 2977  It is a  non bike command      0
# 2978  It is a  non bike command      0
# 2979  It is a  non bike command      0
#
# [2980 rows x 6 columns]

# %%
df['Subclass'].unique()
# Out:
# array(['Edge', 'Cloud', 'Update', 'Miscellaneous', 'Not needed'],
#       dtype=object)

# %%
new_df = df[df['Subclass'] != 'Not needed'].reset_index(drop=True)
new_df
# Out:
#      Class       Subclass SubclassCategory  \
# 0     Bike           Edge     Battery/Fuel
# 1     Bike           Edge     Battery/Fuel
# 2     Bike           Edge     Battery/Fuel
# 3     Bike           Edge     Battery/Fuel
# 4     Bike           Edge     Battery/Fuel
# ...    ...            ...              ...
# 1425  Bike  Miscellaneous        Temporary
# 1426  Bike  Miscellaneous        Temporary
# 1427  Bike  Miscellaneous        Temporary
# 1428  Bike  Miscellaneous        Temporary
# 1429  Bike  Miscellaneous        Temporary
#
#                                                Commands  \
# 0                     What is my current battery level?
# 1          How much range do I have left on my battery?
# 2        When was the last time my battery was charged?
# 3           How long until my battery is fully charged?
# 4     How long should I charge my vehicle for a suff...
# ...                                                 ...
# 1425      Perform a bike suspension linkage lubrication
# 1426          Activate bike's adaptive throttle control
# 1427  Check for loose bolts in the bike's rear wheel...
# 1428             Perform a bike clutch cable inspection
# 1429  Activate bike's cruise control with speed limiter
#
#                                                Response  Label
# 0                                  Updating please wait      1
# 1                                  Updating please wait      1
# 2                                  Updating please wait      1
# 3                                  Updating please wait      1
# 4                                  Updating please wait      1
# ...                                                 ...    ...
# 1425  Regularly lubricate the suspension linkage for...      1
# 1426  Utilize adaptive throttle control for personal...      1
# 1427  Inspect and tighten any loose bolts in the rea...      1
# 1428  Inspect the clutch cable for signs of wear and...      1
# 1429  Utilize cruise control with speed limiter for ...      1
#
# [1430 rows x 6 columns]

# %%
new_df['Subclass'].unique()
# Out:
# array(['Edge', 'Cloud', 'Update', 'Miscellaneous'], dtype=object)

# %%
X=new_df['Commands']
X
# Out:
# 0                       What is my current battery level?
# 1            How much range do I have left on my battery?
# 2          When was the last time my battery was charged?
# 3             How long until my battery is fully charged?
# 4       How long should I charge my vehicle for a suff...
#                               ...
# 1425        Perform a bike suspension linkage lubrication
# 1426            Activate bike's adaptive throttle control
# 1427    Check for loose bolts in the bike's rear wheel...
# 1428               Perform a bike clutch cable inspection
# 1429    Activate bike's cruise control with speed limiter
# Name: Commands, Length: 1430, dtype: object

# %%
# Automatically convert categorical values to labels
new_df['Subclass_Label'], _ = pd.factorize(new_df['Subclass'])
new_df['Subclass_Label']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1425    3
# 1426    3
# 1427    3
# 1428    3
# 1429    3
# Name: Subclass_Label, Length: 1430, dtype: int64

# %%
new_df
# Out:
#      Class       Subclass SubclassCategory  \
# 0     Bike           Edge     Battery/Fuel
# 1     Bike           Edge     Battery/Fuel
# 2     Bike           Edge     Battery/Fuel
# 3     Bike           Edge     Battery/Fuel
# 4     Bike           Edge     Battery/Fuel
# ...    ...            ...              ...
# 1425  Bike  Miscellaneous        Temporary
# 1426  Bike  Miscellaneous        Temporary
# 1427  Bike  Miscellaneous        Temporary
# 1428  Bike  Miscellaneous        Temporary
# 1429  Bike  Miscellaneous        Temporary
#
#                                                Commands  \
# 0                     What is my current battery level?
# 1          How much range do I have left on my battery?
# 2        When was the last time my battery was charged?
# 3           How long until my battery is fully charged?
# 4     How long should I charge my vehicle for a suff...
# ...                                                 ...
# 1425      Perform a bike suspension linkage lubrication
# 1426          Activate bike's adaptive throttle control
# 1427  Check for loose bolts in the bike's rear wheel...
# 1428             Perform a bike clutch cable inspection
# 1429  Activate bike's cruise control with speed limiter
#
#                                                Response  Label  Subclass_Label
# 0                                  Updating please wait      1               0
# 1                                  Updating please wait      1               0
# 2                                  Updating please wait      1               0
# 3                                  Updating please wait      1               0
# 4                                  Updating please wait      1               0
# ...                                                 ...    ...             ...
# 1425  Regularly lubricate the suspension linkage for...      1               3
# 1426  Utilize adaptive throttle control for personal...      1               3
# 1427  Inspect and tighten any loose bolts in the rea...      1               3
# 1428  Inspect the clutch cable for signs of wear and...      1               3
# 1429  Utilize cruise control with speed limiter for ...      1               3
#
# [1430 rows x 7 columns]

# %%
y=new_df['Subclass_Label']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1425    3
# 1426    3
# 1427    3
# 1428    3
# 1429    3
# Name: Subclass_Label, Length: 1430, dtype: int64

# %%
y.unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
# Assuming 'Class' column contains the commands and 'Label' column contains the labels for multiclass classification
# Assuming df is your DataFrame
# X = df['Commands']  # Input features
# y = df['Label']      # Target variable

# Tokenize the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
X_sequences = tokenizer.texts_to_sequences(X)

# Padding sequences to make them of equal length
max_sequence_length = max([len(seq) for seq in X_sequences])
X_padded = pad_sequences(X_sequences, maxlen=max_sequence_length, padding='post')

# Convert labels to one-hot encoding
y_encoded = to_categorical(y)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Define the RNN model for multiclass classification
num_classes = len(np.unique(y))  # Number of unique classes
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_sequence_length))
model.add(LSTM(256, return_sequences=True))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(32))
model.add(Dense(num_classes, activation='softmax'))  # Use softmax activation for multiclass classification

# Compile the model with categorical cross-entropy loss
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=15, batch_size=64, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/15
# 18/18 [==============================] - 8s 165ms/step - loss: 1.2852 - accuracy: 0.3427 - val_loss: 1.0184 - val_accuracy: 0.5035
# Epoch 2/15
# 18/18 [==============================] - 2s 101ms/step - loss: 0.8684 - accuracy: 0.5516 - val_loss: 0.8955 - val_accuracy: 0.5315
# Epoch 3/15
# 18/18 [==============================] - 2s 102ms/step - loss: 0.6832 - accuracy: 0.6302 - val_loss: 0.7470 - val_accuracy: 0.7203
# Epoch 4/15
# 18/18 [==============================] - 2s 108ms/step - loss: 0.5376 - accuracy: 0.7981 - val_loss: 0.8841 - val_accuracy: 0.6818
# Epoch 5/15
# 18/18 [==============================] - 2s 112ms/step - loss: 0.4785 - accuracy: 0.8243 - val_loss: 0.5702 - val_accuracy: 0.8112
# Epoch 6/15
# 18/18 [==============================] - 2s 102ms/step - loss: 0.2999 - accuracy: 0.9170 - val_loss: 0.4753 - val_accuracy: 0.8531
# Epoch 7/15
# 18/18 [==============================] - 2s 101ms/step - loss: 0.2437 - accuracy: 0.9344 - val_loss: 0.4798 - val_accuracy: 0.8601
# Epoch 8/15
# 18/18 [==============================] - 2s 105ms/step - loss: 0.1588 - accuracy: 0.9677 - val_loss: 0.6365 - val_accuracy: 0.8287
# Epoch 9/15
# 18/18 [==============================] - 2s 105ms/step - loss: 0.3953 - accuracy: 0.8829 - val_loss: 0.5089 - val_accuracy: 0.8427
# Epoch 10/15
# 18/18 [==============================] - 2s 105ms/step - loss: 0.2723 - accuracy: 0.9231 - val_loss: 0.5360 - val_accuracy: 0.8322
# Epoch 11/15
# 18/18 [==============================] - 2s 108ms/step - loss: 0.2242 - accuracy: 0.9414 - val_loss: 0.4244 - val_accuracy: 0.8881
# Epoch 12/15
# 18/18 [==============================] - 2s 106ms/step - loss: 0.1350 - accuracy: 0.9720 - val_loss: 0.4326 - val_accuracy: 0.8916
# Epoch 13/15
# 18/18 [==============================] - 2s 106ms/step - loss: 0.1049 - accuracy: 0.9808 - val_loss: 0.4248 - val_accuracy: 0.8951
# Epoch 14/15
# 18/18 [==============================] - 2s 106ms/step - loss: 0.0864 - accuracy: 0.9843 - val_loss: 0.4580 - val_accuracy: 0.8881
# Epoch 15/15
# 18/18 [==============================] - 2s 107ms/step - loss: 0.0865 - accuracy: 0.9825 - val_loss: 0.6848 - val_accuracy: 0.8287
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6848 - accuracy: 0.8287
# Test Loss: 0.6847513318061829
# Test Accuracy: 0.8286713361740112

# %%
# Function to predict the class of a command
def predict_class(command):
    sequence = tokenizer.texts_to_sequences([command])
    padded_sequence = pad_sequences(sequence, maxlen=max_sequence_length, padding='post')
    prediction = model.predict(padded_sequence)
    predicted_class_index = np.argmax(prediction)
    return predicted_class_index

# %%
y_encoded[11]
print(y.count())
print(y.unique())
# Out:
# 1430
# [0 1 2 3]

# %%
tokenizer

# %%
import joblib
# Assuming model is your trained model object
joblib.dump(model, './RNN_save_model/RNN_Multiclass_Subclass3_t3.joblib')
joblib.dump(tokenizer, './RNN_save_model/tokenizert3.joblib')
joblib.dump(max_sequence_length, './RNN_save_model/max_sequence_length_mainModel3.joblib')
# Out:
# ['./RNN_save_model/max_sequence_length_mainModel3.joblib']

# %%
# Example usage:
command_input = input("Enter a command: ")
print(command_input)
prediction = predict_class(command_input)
if(prediction==0):
    print("Edge :", prediction)
elif(prediction==1):
    print("Cloud :", prediction)
elif(prediction==2):
    print("Update :",prediction)
elif(prediction==3):
    print("Miscellaneous :",prediction)
else:
    print("Dont know")
# Out:
# hi tvs
# 1/1 [==============================] - 0s 14ms/step
# Edge : 0

# %%
#######################################################################################################################

# %%
tokenizer

# %%
df_edge = df[df['Subclass'] == 'Edge']
df_cloud = df[df['Subclass'] == 'Cloud']
df_update = df[df['Subclass'] == 'Update']
df_miscellaneous = df[df['Subclass'] == 'Miscellaneous']
df_notneeded = df[df['Subclass'] == 'Not needed']

df_edge.reset_index(drop=True, inplace=True)
df_cloud.reset_index(drop=True, inplace=True)
df_update.reset_index(drop=True, inplace=True)
df_miscellaneous.reset_index(drop=True, inplace=True)
df_notneeded.reset_index(drop=True, inplace=True)

# %%
df_edge
# Out:
#     Class Subclass SubclassCategory  \
# 0    Bike     Edge     Battery/Fuel
# 1    Bike     Edge     Battery/Fuel
# 2    Bike     Edge     Battery/Fuel
# 3    Bike     Edge     Battery/Fuel
# 4    Bike     Edge     Battery/Fuel
# ..    ...      ...              ...
# 382  Bike     Edge            Basic
# 383  Bike     Edge            Basic
# 384  Bike     Edge            Basic
# 385  Bike     Edge     Battery/Fuel
# 386  Bike     Edge            Tires
#
#                                               Commands  \
# 0                    What is my current battery level?
# 1         How much range do I have left on my battery?
# 2       When was the last time my battery was charged?
# 3          How long until my battery is fully charged?
# 4    How long should I charge my vehicle for a suff...
# ..                                                 ...
# 382                                       Start Engine
# 383                                        Stop Engine
# 384                          Activate bike's rain mode
# 385              Perform a bike fuel injector cleaning
# 386        Activate bike's tire temperature monitoring
#
#                                               Response  Label
# 0                                 Updating please wait      1
# 1                                 Updating please wait      1
# 2                                 Updating please wait      1
# 3                                 Updating please wait      1
# 4                                 Updating please wait      1
# ..                                                 ...    ...
# 382   Processing your fuel related command please wait      1
# 383   Processing your fuel related command please wait      1
# 384  Utilize rain mode for safer riding in wet cond...      1
# 385  Clean fuel injectors for improved fuel atomiza...      1
# 386  Utilize tire temperature monitoring for optima...      1
#
# [387 rows x 6 columns]

# %%
df_cloud
# Out:
#     Class Subclass SubclassCategory                               Commands  \
# 0    Bike    Cloud      Songs/media                    Play "XYZ" by "ABC"
# 1    Bike    Cloud      Songs/media                 Play my favorite song.
# 2    Bike    Cloud      Songs/media                   Start playing music.
# 3    Bike    Cloud      Songs/media                   Shuffle my playlist.
# 4    Bike    Cloud      Songs/media                 Play the latest track.
# ..    ...      ...              ...                                    ...
# 443  Bike    Cloud     Traffic/Maps  Navigate to hyderbad/kolkata/banglore
# 444  Bike    Cloud          Weather                 Check weather forecast
# 445  Bike    Cloud      Songs/media                             Play music
# 446  Bike    Cloud     Traffic/Maps                    Take a scenic route
# 447  Bike    Cloud     Traffic/Maps              Check for traffic updates
#
#                                               Response  Label
# 0         Please wait, your request is been processed.      1
# 1         Please wait, your request is been processed.      1
# 2         Please wait, your request is been processed.      1
# 3         Please wait, your request is been processed.      1
# 4         Please wait, your request is been processed.      1
# ..                                                 ...    ...
# 443  You receive turn-by-turn directions to [destin...      1
# 444                 The weather forecast is [weather].      1
# 445                Your favorite music starts playing.      1
# 446            The navigation suggests a scenic route.      1
# 447        There are no traffic updates at the moment.      1
#
# [448 rows x 6 columns]

# %%
df_update
# Out:
#     Class Subclass SubclassCategory  \
# 0    Bike   Update           Cancel
# 1    Bike   Update           Cancel
# 2    Bike   Update           Cancel
# 3    Bike   Update           Cancel
# 4    Bike   Update           Cancel
# ..    ...      ...              ...
# 307  Bike   Update            Check
# 308  Bike   Update            Check
# 309  Bike   Update            Check
# 310  Bike   Update            Check
# 311  Bike   Update            Check
#
#                                               Commands  \
# 0                   Abort pending bike firmware update
# 1                     Abort pending bike system update
# 2                       Abort software update for bike
# 3                          Cancel bike firmware update
# 4                  Cancel bike software update process
# ..                                                 ...
# 307  Look into firmware update schedules for my ele...
# 308  Verify the compatibility of the latest softwar...
# 309  Find out if there are any performance improvem...
# 310  Check if there are any security patches includ...
# 311  Inquire about the process for manually trigger...
#
#                       Response  Label
# 0         Aborting please wait      1
# 1         Aborting please wait      1
# 2         Aborting please wait      1
# 3         Aborting please wait      1
# 4         Aborting please wait      1
# ..                         ...    ...
# 307  Checking for your request      1
# 308  Checking for your request      1
# 309  Checking for your request      1
# 310  Checking for your request      1
# 311  Checking for your request      1
#
# [312 rows x 6 columns]

# %%
df_miscellaneous
# Out:
#     Class       Subclass SubclassCategory  \
# 0    Bike  Miscellaneous        Temporary
# 1    Bike  Miscellaneous        Temporary
# 2    Bike  Miscellaneous        Temporary
# 3    Bike  Miscellaneous        Temporary
# 4    Bike  Miscellaneous        Temporary
# ..    ...            ...              ...
# 278  Bike  Miscellaneous        Temporary
# 279  Bike  Miscellaneous        Temporary
# 280  Bike  Miscellaneous        Temporary
# 281  Bike  Miscellaneous        Temporary
# 282  Bike  Miscellaneous        Temporary
#
#                                               Commands  \
# 0                                  Record a voice memo
# 1                                Activate parking mode
# 2                              Deactivate parking mode
# 3                                    Perform a wheelie
# 4                                    Perform a stoppie
# ..                                                 ...
# 278      Perform a bike suspension linkage lubrication
# 279          Activate bike's adaptive throttle control
# 280  Check for loose bolts in the bike's rear wheel...
# 281             Perform a bike clutch cable inspection
# 282  Activate bike's cruise control with speed limiter
#
#                                               Response  Label
# 0                    You start recording a voice memo.      1
# 1                        The bike enters parking mode.      1
# 2                          Parking mode is turned off.      1
# 3    Performing wheelies is unsafe and against traf...      1
# 4    Performing stoppies is unsafe and against traf...      1
# ..                                                 ...    ...
# 278  Regularly lubricate the suspension linkage for...      1
# 279  Utilize adaptive throttle control for personal...      1
# 280  Inspect and tighten any loose bolts in the rea...      1
# 281  Inspect the clutch cable for signs of wear and...      1
# 282  Utilize cruise control with speed limiter for ...      1
#
# [283 rows x 6 columns]

# %%
df_notneeded
# Out:
#         Class    Subclass SubclassCategory                          Commands  \
# 0     NonBike  Not needed               NC          Bake cookies in the oven
# 1     NonBike  Not needed               NC            Write a poem on nature
# 2     NonBike  Not needed               NC  Calculate the square root of 144
# 3     NonBike  Not needed               NC          Paint a sunset landscape
# 4     NonBike  Not needed               NC             Compose a jazz melody
# ...       ...         ...              ...                               ...
# 1545  NonBike  Not needed               NC          Perform my pets marriage
# 1546  NonBike  Not needed               NC          Perform my dogs marriage
# 1547  NonBike  Not needed               NC              check blood pressure
# 1548  NonBike  Not needed               NC           check balloon pressure
# 1549  NonBike  Not needed               NC                    check my books
#
#                                                Response  Label
# 0     The oven is preheating. Let's bake some delici...      0
# 1     Embarking on a poetic journey to capture the b...      0
# 2                         The square root of 144 is 12.      0
# 3     Immerse yourself in painting a serene sunset l...      0
# 4     Creating a soulful jazz melody that resonates ...      0
# ...                                                 ...    ...
# 1545                          It is a  non bike command      0
# 1546                          It is a  non bike command      0
# 1547                          It is a  non bike command      0
# 1548                          It is a  non bike command      0
# 1549                          It is a  non bike command      0
#
# [1550 rows x 6 columns]

# %%
# Function to predict the class of a command
def predict_class(command,tokenizer,model,max_sequence_length):
    sequence = tokenizer.texts_to_sequences([command])
    padded_sequence = pad_sequences(sequence, maxlen=max_sequence_length, padding='post')
    prediction = model.predict(padded_sequence)
    predicted_class_index = np.argmax(prediction)
    return predicted_class_index

# %%
def train_model_subClassCategory(df,filename,subclassCat):
    
    X=df['Commands']

    df=df.copy()
    # Automatically convert categorical values to labels
    df['Subclass_Label_Category'], _ = pd.factorize(df['SubclassCategory'])

    # Save DataFrame to a CSV file
    df.to_csv(filename, index=False)

    y=df['Subclass_Label_Category']

    # Tokenize the text data
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(X)
    X_sequences = tokenizer.texts_to_sequences(X)

    # Padding sequences to make them of equal length
    max_sequence_length = max([len(seq) for seq in X_sequences])
    X_padded = pad_sequences(X_sequences, maxlen=max_sequence_length, padding='post')

    # Convert labels to one-hot encoding
    y_encoded = to_categorical(y)

    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_padded, y_encoded, test_size=0.2, random_state=42,stratify=y_encoded)

    # Define the RNN model for multiclass classification
    num_classes = len(np.unique(y))  # Number of unique classes
    model = Sequential()
    model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_sequence_length))

    model.add(LSTM(256, return_sequences=True))
    model.add(LSTM(128, return_sequences=True))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(32))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax activation for multiclass classification

    # Compile the model with categorical cross-entropy loss
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train, y_train, epochs=15, batch_size=64, validation_data=(X_test, y_test))
    
    # Assuming model is your trained model object
    joblib.dump(model, './RNN_save_model/'+subclassCat+'/RNN_Multiclass_SubclassCategory.joblib')
    joblib.dump(tokenizer, './RNN_save_model/'+subclassCat+'/tokenizer.joblib')
    joblib.dump(max_sequence_length, './RNN_save_model/'+subclassCat+'/max_sequence_length.joblib')
    

    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test)
    print("Test Loss:", loss)
    print("Test Accuracy:", accuracy)
    
    return model,tokenizer, max_sequence_length

# %%
######################################################EDGE########################################################
filename="df_edge.csv"
subclasscat="EDGE"
model,tokenizer, max_sequence_length=train_model_subClassCategory(df_edge,filename,subclasscat)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 7s 319ms/step - loss: 1.3661 - accuracy: 0.3301 - val_loss: 1.3246 - val_accuracy: 0.5513
# Epoch 2/15
# 5/5 [==============================] - 0s 60ms/step - loss: 1.3136 - accuracy: 0.3981 - val_loss: 1.2738 - val_accuracy: 0.3718
# Epoch 3/15
# 5/5 [==============================] - 0s 62ms/step - loss: 1.2188 - accuracy: 0.4110 - val_loss: 1.0239 - val_accuracy: 0.6795
# Epoch 4/15
# 5/5 [==============================] - 0s 61ms/step - loss: 0.9909 - accuracy: 0.5922 - val_loss: 0.9175 - val_accuracy: 0.6282
# Epoch 5/15
# 5/5 [==============================] - 0s 58ms/step - loss: 0.8584 - accuracy: 0.6214 - val_loss: 0.8000 - val_accuracy: 0.6282
# Epoch 6/15
# 5/5 [==============================] - 0s 62ms/step - loss: 0.7697 - accuracy: 0.6084 - val_loss: 0.7904 - val_accuracy: 0.7051
# Epoch 7/15
# 5/5 [==============================] - 0s 62ms/step - loss: 0.6858 - accuracy: 0.7184 - val_loss: 0.6734 - val_accuracy: 0.7179
# Epoch 8/15
# 5/5 [==============================] - 0s 62ms/step - loss: 0.5645 - accuracy: 0.8350 - val_loss: 0.5424 - val_accuracy: 0.8205
# Epoch 9/15
# 5/5 [==============================] - 0s 61ms/step - loss: 0.4057 - accuracy: 0.9126 - val_loss: 0.3973 - val_accuracy: 0.8590
# Epoch 10/15
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2611 - accuracy: 0.9126 - val_loss: 0.4059 - val_accuracy: 0.8333
# Epoch 11/15
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1718 - accuracy: 0.9417 - val_loss: 0.3670 - val_accuracy: 0.8718
# Epoch 12/15
# 5/5 [==============================] - 0s 66ms/step - loss: 0.1073 - accuracy: 0.9903 - val_loss: 0.3340 - val_accuracy: 0.8846
# Epoch 13/15
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0667 - accuracy: 0.9968 - val_loss: 0.3448 - val_accuracy: 0.8974
# Epoch 14/15
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0573 - accuracy: 0.9968 - val_loss: 0.4480 - val_accuracy: 0.8718
# Epoch 15/15
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0650 - accuracy: 0.9838 - val_loss: 0.3972 - val_accuracy: 0.8846
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3972 - accuracy: 0.8846
# Test Loss: 0.39723214507102966
# Test Accuracy: 0.8846153616905212

# %%
# Load the model from and tokenizer
model = joblib.load('./RNN_save_model/'+subclasscat+'/RNN_Multiclass_SubclassCategory.joblib')
tokenizer = joblib.load('./RNN_save_model/'+subclasscat+'/tokenizer.joblib')
max_sequence_length=joblib.load('./RNN_save_model/'+subclasscat+'/max_sequence_length.joblib')

# %%
# Example usage:
command = input("Enter a command: ")
print(command)
prediction = predict_class(command, tokenizer,model, max_sequence_length)
if(prediction==0):
    print("Edge -> Battery Fuel:", prediction)
elif(prediction==1):
    print("Edge -> Tires:", prediction)
elif(prediction==2):
    print("Edge -> Greetings :",prediction)
elif(prediction==3):
    print("Edge -> Basic :",prediction)
else:
    print("Dont know")
# Out:
# hi tvs
# 1/1 [==============================] - 1s 1s/step
# Edge -> Greetings : 2

# %%
########################################################CLOUD###############################################
filename="df_cloud.csv"
subclasscat="CLOUD"
model,tokenizer, max_sequence_length=train_model_subClassCategory(df_cloud,filename,subclasscat)
# Out:
# Epoch 1/15
# 6/6 [==============================] - 7s 300ms/step - loss: 1.3867 - accuracy: 0.2542 - val_loss: 1.3740 - val_accuracy: 0.3222
# Epoch 2/15
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3783 - accuracy: 0.3184 - val_loss: 1.3613 - val_accuracy: 0.3222
# Epoch 3/15
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3082 - accuracy: 0.3603 - val_loss: 1.1347 - val_accuracy: 0.5889
# Epoch 4/15
# 6/6 [==============================] - 0s 83ms/step - loss: 0.9817 - accuracy: 0.6592 - val_loss: 0.7444 - val_accuracy: 0.7222
# Epoch 5/15
# 6/6 [==============================] - 1s 86ms/step - loss: 0.7067 - accuracy: 0.7318 - val_loss: 0.7080 - val_accuracy: 0.7222
# Epoch 6/15
# 6/6 [==============================] - 1s 87ms/step - loss: 0.5784 - accuracy: 0.7821 - val_loss: 0.5686 - val_accuracy: 0.7667
# Epoch 7/15
# 6/6 [==============================] - 1s 90ms/step - loss: 0.5800 - accuracy: 0.7570 - val_loss: 0.4250 - val_accuracy: 0.8667
# Epoch 8/15
# 6/6 [==============================] - 1s 90ms/step - loss: 0.4486 - accuracy: 0.8715 - val_loss: 0.5820 - val_accuracy: 0.8111
# Epoch 9/15
# 6/6 [==============================] - 1s 90ms/step - loss: 0.3710 - accuracy: 0.9022 - val_loss: 0.4373 - val_accuracy: 0.8778
# Epoch 10/15
# 6/6 [==============================] - 1s 87ms/step - loss: 0.3203 - accuracy: 0.8966 - val_loss: 0.3635 - val_accuracy: 0.8667
# Epoch 11/15
# 6/6 [==============================] - 1s 89ms/step - loss: 0.1851 - accuracy: 0.9497 - val_loss: 0.3124 - val_accuracy: 0.9333
# Epoch 12/15
# 6/6 [==============================] - 1s 99ms/step - loss: 0.1781 - accuracy: 0.9553 - val_loss: 0.3245 - val_accuracy: 0.9111
# Epoch 13/15
# 6/6 [==============================] - 1s 103ms/step - loss: 0.1234 - accuracy: 0.9693 - val_loss: 0.3256 - val_accuracy: 0.8778
# Epoch 14/15
# 6/6 [==============================] - 1s 111ms/step - loss: 0.1098 - accuracy: 0.9637 - val_loss: 0.2780 - val_accuracy: 0.9111
# Epoch 15/15
# 6/6 [==============================] - 1s 105ms/step - loss: 0.0736 - accuracy: 0.9916 - val_loss: 0.2482 - val_accuracy: 0.9444
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2482 - accuracy: 0.9444
# Test Loss: 0.24817907810211182
# Test Accuracy: 0.9444444179534912

# %%
# Load the model from and tokenizer
model = joblib.load('./RNN_save_model/'+subclasscat+'/RNN_Multiclass_SubclassCategory.joblib')
tokenizer = joblib.load('./RNN_save_model/'+subclasscat+'/tokenizer.joblib')
max_sequence_length=joblib.load('./RNN_save_model/'+subclasscat+'/max_sequence_length.joblib')

# %%
# Example usage:
command = input("Enter a command: ")
print(command)
prediction = predict_class(command, tokenizer,model, max_sequence_length)
if(prediction==0):
    print("Cloud -> Song Media:", prediction)
elif(prediction==1):
    print("Cloud -> News Notification:", prediction)
elif(prediction==2):
    print("Cloud -> Weather :",prediction)
elif(prediction==3):
    print("Cloud -> Traffic Maps :",prediction)
else:
    print("Dont know")
# Out:
# play again the same song
# 1/1 [==============================] - 0s 29ms/step
# Cloud -> Song Media: 0

# %%
###########################################Update#################################################
filename="df_update.csv"
subclasscat="UPDATE"
model,tokenizer, max_sequence_length=train_model_subClassCategory(df_update,filename,subclasscat)
# Out:
# Epoch 1/15
# 4/4 [==============================] - 6s 400ms/step - loss: 1.0926 - accuracy: 0.3655 - val_loss: 1.0658 - val_accuracy: 0.6984
# Epoch 2/15
# 4/4 [==============================] - 0s 54ms/step - loss: 1.0324 - accuracy: 0.7349 - val_loss: 0.8955 - val_accuracy: 0.7619
# Epoch 3/15
# 4/4 [==============================] - 0s 49ms/step - loss: 0.8054 - accuracy: 0.7068 - val_loss: 0.5940 - val_accuracy: 0.7619
# Epoch 4/15
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5580 - accuracy: 0.8594 - val_loss: 0.4177 - val_accuracy: 0.9524
# Epoch 5/15
# 4/4 [==============================] - 0s 57ms/step - loss: 0.3501 - accuracy: 0.9438 - val_loss: 0.2178 - val_accuracy: 0.9524
# Epoch 6/15
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1673 - accuracy: 0.9799 - val_loss: 0.1027 - val_accuracy: 0.9841
# Epoch 7/15
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0939 - accuracy: 0.9880 - val_loss: 0.0483 - val_accuracy: 1.0000
# Epoch 8/15
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 9/15
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 10/15
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 11/15
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 12/15
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9841
# Epoch 13/15
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0312 - accuracy: 0.9960 - val_loss: 0.0906 - val_accuracy: 0.9841
# Epoch 14/15
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0299 - accuracy: 0.9960 - val_loss: 0.0889 - val_accuracy: 0.9841
# Epoch 15/15
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0287 - accuracy: 0.9960 - val_loss: 0.0769 - val_accuracy: 0.9841
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0769 - accuracy: 0.9841
# Test Loss: 0.07692896574735641
# Test Accuracy: 0.9841269850730896

# %%
# Load the model from and tokenizer
model = joblib.load('./RNN_save_model/'+subclasscat+'/RNN_Multiclass_SubclassCategory.joblib')
tokenizer = joblib.load('./RNN_save_model/'+subclasscat+'/tokenizer.joblib')
max_sequence_length=joblib.load('./RNN_save_model/'+subclasscat+'/max_sequence_length.joblib')

# %%
# Example usage:
command = input("Enter a command: ")
print(command)
prediction = predict_class(command, tokenizer,model, max_sequence_length)
if(prediction==0):
    print("Update -> Cancel:", prediction)
elif(prediction==1):
    print("Update -> Perform:", prediction)
elif(prediction==2):
    print("Update -> Check:",prediction)
else:
    print("Dont know")
# Out:
# stop current updates
# 1/1 [==============================] - 0s 12ms/step
# Update -> Cancel: 0
